# %% [markdown]
# Exploratory Data Analysis of GTA: San Andreas Vehicle Stats using Seaborn
#
# Don't forget to upvote if you enjoy my work :)
#
# # Introduction
#
# As a fan of Grand Theft Auto, I recently revisited the iconic San Andreas after exams - and while playing, I became curious about the in-game cars and their hidden stats. So I decided to combine my love for games with my interest in data analysis by performing an EDA on vehicle stats extracted from the game files.
#
# In this notebook, you'll find:
# - Technical information about 162 vehicles from GTA: San Andreas
# - Cleaned and well-structured dataset
# - Descriptive statistics and visualizations
# - Analysis of relationships between vehicle attributes (e.g., speed vs weight)

# %% [markdown]
# Import libraries:
#
# These are the only libraries we're going to use for this EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Overview
#
# The data was sourced from gta.fandom.com and loaded into a pandas DataFrame. I examined the structure of the dataset, checked for missing values, and used .info() and .describe() to understand column types and basic distributions. I prepared the dataset, so you can use it for your ideas: [Clean and ready GTA:SA Vehicle Stats dataset](https://www.kaggle.com/datasets/marcelbiezunski/gta-san-andreas-vehicle-stats-full-handling-data)

# %%
dataset = 'gta_sa_vehicle_stats_ready.csv'
df = pd.read_csv(dataset)
pd.set_option('display.max_columns', None)
df
# Out:
#     identifier  mass_(kg)  turn_mass_(kg)  drag_multiplier  center_of_mass_x  \
# 0     LANDSTAL     1700.0          5008.3              2.5               0.0
# 1      BRAVURA     1300.0          2200.0              1.7               0.0
# 2      BUFFALO     1500.0          4000.0              2.0               0.0
# 3      LINERUN     3800.0         19953.2              5.0               0.0
# 4        PEREN     1200.0          3000.0              2.5               0.0
# ..         ...        ...             ...              ...               ...
# 157     STAIRS     1000.0          2500.0              5.0               0.0
# 158    BOXBURG     5500.0         23489.6              3.0               0.0
# 159   FARM_TR1      400.0           400.0              5.0               0.0
# 160   UTIL_TR1     1000.0          1354.2              5.0               0.0
# 161     ROLLER     1000.0          1354.2              4.0               0.0
#
#      center_of_mass_y  center_of_mass_z  center_of_mass_%submerged  \
# 0                 0.0              -0.3                         85
# 1                 0.3               0.0                         70
# 2                 0.0              -0.1                         85
# 3                 0.0              -0.2                         90
# 4                 0.1               0.0                         70
# ..                ...               ...                        ...
# 157               0.4              -0.2                         70
# 158               0.0               0.0                         80
# 159              -0.4               0.0                         70
# 160               0.0               0.0                         70
# 161               0.0              -0.1                         70
#
#      traction_multiplier  traction_loss  traction_bias(%)  #_of_gears  \
# 0                   0.75           0.85              0.50           5
# 1                   0.65           0.80              0.52           9
# 2                   0.70           0.90              0.50           9
# 3                   0.95           0.65              0.40           9
# 4                   0.70           0.90              0.48           9
# ..                   ...            ...               ...         ...
# 157                 1.00           0.85              0.50           3
# 158                 0.82           0.70              0.46           5
# 159                 0.60           0.85              0.50           3
# 160                 1.00           0.85              0.50           3
# 161                 0.55           0.85              0.50           3
#
#      max_velocity(km/h)  acceleration(ms^2)  interia drive_type engine_type  \
# 0                 160.0                25.0     20.0          4           D
# 1                 144.0                15.0     10.0      Front      Petrol
# 2                 200.0                28.0      5.0       Rear      Petrol
# 3                 160.0                25.0     30.0       Rear      Diesel
# 4                 150.0                18.0     20.0      Front      Petrol
# ..                  ...                 ...      ...        ...         ...
# 157               160.0                20.0     30.0       Rear    Electric
# 158               140.0                14.0     25.0       Rear      Diesel
# 159               160.0                20.0     30.0       Rear    Electric
# 160               160.0                20.0     30.0       Rear    Electric
# 161               160.0                15.0     30.0          4    Electric
#
#      brakes_deceleration(ms^2)  brakes_bias(%)  abs  steering_lock_(°)  \
# 0                          6.2            0.60    0               35.0
# 1                          8.0            0.80    0               30.0
# 2                         11.0            0.45    0               30.0
# 3                          8.0            0.30    0               25.0
# 4                          4.0            0.80    0               30.0
# ..                         ...             ...  ...                ...
# 157                        5.0            0.50    0               30.0
# 158                        4.5            0.60    0               30.0
# 159                        5.0            0.50    0               30.0
# 160                        5.0            0.50    0               30.0
# 161                       13.0            0.50    0               30.0
#
#      suspension_force_level  suspension_damping_level  \
# 0                       2.4                      0.08
# 1                       1.3                      0.08
# 2                       1.2                      0.12
# 3                       1.6                      0.06
# 4                       1.4                      0.10
# ..                      ...                       ...
# 157                     2.0                      0.09
# 158                     0.9                      0.08
# 159                     1.0                      0.10
# 160                     2.0                      0.09
# 161                     1.0                      0.09
#
#      suspension_high_speed_com_damping  suspension_lines_upper_limit  \
# 0                                  0.0                          0.28
# 1                                  0.0                          0.31
# 2                                  0.0                          0.28
# 3                                  0.0                          0.40
# 4                                  0.0                          0.37
# ..                                 ...                           ...
# 157                                0.0                          0.25
# 158                                0.0                          0.25
# 159                                0.0                          0.25
# 160                                0.0                          0.25
# 161                                0.0                          0.28
#
#      suspension_lines_lower_limit  \
# 0                           -0.14
# 1                           -0.15
# 2                           -0.24
# 3                           -0.20
# 4                           -0.17
# ..                            ...
# 157                         -0.10
# 158                         -0.25
# 159                         -0.10
# 160                         -0.10
# 161                         -0.13
#
#      suspension_lines_bias_between_front_and_rear  \
# 0                                            0.50
# 1                                            0.57
# 2                                            0.50
# 3                                            0.50
# 4                                            0.50
# ..                                            ...
# 157                                          0.50
# 158                                          0.35
# 159                                          0.50
# 160                                          0.50
# 161                                          0.50
#
#      suspension_anti-dive_multiplier  seat_offset_distance  \
# 0                               0.25                  0.27
# 1                               0.00                  0.26
# 2                               0.40                  0.25
# 3                               0.00                  0.65
# 4                               0.00                  0.20
# ..                               ...                   ...
# 157                             0.00                  0.26
# 158                             0.60                  0.36
# 159                             0.00                  0.26
# 160                             0.00                  0.26
# 161                             0.00                  0.26
#
#      collision_damage_multiplier  monetary_value_($) model_flags  \
# 0                           0.23               25000          20
# 1                           0.50                9000           1
# 2                           0.50               35000        2800
# 3                           0.25               35000        6000
# 4                           0.60               10000          20
# ..                           ...                 ...         ...
# 157                         0.50                9000        3100
# 158                         0.40               22000        4009
# 159                         0.50                9000        3100
# 160                         0.50                9000        3100
# 161                         0.50                9000        1100
#
#     handling_flags lights_front lights_rear  lights_anim_group
# 0           500002            0           1                0.0
# 1                1         Long        Long                0.0
# 2         10200000        Small       Small                0.0
# 3              200         Long       Small                2.0
# 4                0        Small       Small                0.0
# ..             ...          ...         ...                ...
# 157              4        Small       Small                0.0
# 158            201         Long        Tall               13.0
# 159              4        Small       Small                0.0
# 160              4        Small       Small                0.0
# 161           8804        Small       Small                0.0
#
# [162 rows x 36 columns]

# %% [markdown]
# # Understanding the Dataset Structure
#
# Before diving deeper into analysis, it's important to get a general overview of the dataset. In this section, I examine the structure and content of the data using several basic exploratory methods:
#
# - dtypes – to check the data types of each column, which helps us understand whether the features are numerical, categorical, or textual.
# - info() – to get a summary of the dataset, including non-null counts and memory usage.
# - describe() – to generate basic statistical summaries for numerical columns such as mean, standard deviation, min/max, and quartiles.
# - unique() / nunique() – to inspect the diversity of values.
#
# This initial exploration helps us spot potential issues such as missing values, unexpected data types or strange distributions, and gives us a clearer picture of what kind of information we’re working with.

# %%
for c in df.columns:
    if c not in ['identifier', 'drive_type', 'engine_type', 'model_flags',
                 'handling_flags', 'lights_front', 'lights_rear']:
        df[c] = pd.to_numeric(df[c])

# %%
df.select_dtypes(include='object')
# Out:
#     identifier drive_type engine_type model_flags handling_flags lights_front  \
# 0     LANDSTAL          4           D          20         500002            0
# 1      BRAVURA      Front      Petrol           1              1         Long
# 2      BUFFALO       Rear      Petrol        2800       10200000        Small
# 3      LINERUN       Rear      Diesel        6000            200         Long
# 4        PEREN      Front      Petrol          20              0        Small
# ..         ...        ...         ...         ...            ...          ...
# 157     STAIRS       Rear    Electric        3100              4        Small
# 158    BOXBURG       Rear      Diesel        4009            201         Long
# 159   FARM_TR1       Rear    Electric        3100              4        Small
# 160   UTIL_TR1       Rear    Electric        3100              4        Small
# 161     ROLLER          4    Electric        1100           8804        Small
#
#     lights_rear
# 0             1
# 1          Long
# 2         Small
# 3         Small
# 4         Small
# ..          ...
# 157       Small
# 158        Tall
# 159       Small
# 160       Small
# 161       Small
#
# [162 rows x 7 columns]

# %%
df.select_dtypes(include='object').nunique()
# Out:
# identifier        162
# drive_type          4
# engine_type         4
# model_flags        76
# handling_flags     68
# lights_front        4
# lights_rear         6
# dtype: int64

# %%
for c in df.select_dtypes(include='object').columns:
    if c not in ['identifier', 'model_flags', 'handling_flags']:
        print(f'Unique Values in "{c}":', df[c].unique())
# Out:
# Unique Values in "drive_type": ['4' 'Front' 'Rear' 'R']
# Unique Values in "engine_type": ['D' 'Petrol' 'Diesel' 'Electric']
# Unique Values in "lights_front": ['0' 'Long' 'Small' 'Big']
# Unique Values in "lights_rear": ['1' 'Long' 'Small' 'Tall' 'Big' '3']

# %%
df['drive_type'] = df['drive_type'].replace('R', 'Rear')
df['engine_type'] = df['engine_type'].replace('D', 'Diesel')

# %%
for c in ['drive_type', 'engine_type']:
    print(f'Unique Values in {c}:', df[c].unique())
# Out:
# Unique Values in drive_type: ['4' 'Front' 'Rear']
# Unique Values in engine_type: ['Diesel' 'Petrol' 'Electric']

# %%
df['drive_type'] = df['drive_type'].astype('category')
df['engine_type'] = df['engine_type'].astype('category')

# %%
df.dtypes
# Out:
# identifier                                        object
# mass_(kg)                                        float64
# turn_mass_(kg)                                   float64
# drag_multiplier                                  float64
# center_of_mass_x                                 float64
# center_of_mass_y                                 float64
# center_of_mass_z                                 float64
# center_of_mass_%submerged                          int64
# traction_multiplier                              float64
# traction_loss                                    float64
# traction_bias(%)                                 float64
# #_of_gears                                         int64
# max_velocity(km/h)                               float64
# acceleration(ms^2)                               float64
# interia                                          float64
# drive_type                                      category
# engine_type                                     category
# brakes_deceleration(ms^2)                        float64
# brakes_bias(%)                                   float64
# abs                                                int64
# steering_lock_(°)                                float64
# suspension_force_level                           float64
# suspension_damping_level                         float64
# suspension_high_speed_com_damping                float64
# suspension_lines_upper_limit                     float64
# suspension_lines_lower_limit                     float64
# suspension_lines_bias_between_front_and_rear     float64
# suspension_anti-dive_multiplier                  float64
# seat_offset_distance                             float64
# collision_damage_multiplier                      float64
# monetary_value_($)                                 int64
# model_flags                                       object
# handling_flags                                    object
# lights_front                                      object
# lights_rear                                       object
# lights_anim_group                                float64
# dtype: object

# %%
df.select_dtypes(include='category').nunique()
# Out:
# drive_type     3
# engine_type    3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   identifier                                    162 non-null    object
#  1   mass_(kg)                                     162 non-null    float64
#  2   turn_mass_(kg)                                162 non-null    float64
#  3   drag_multiplier                               162 non-null    float64
#  4   center_of_mass_x                              162 non-null    float64
#  5   center_of_mass_y                              162 non-null    float64
#  6   center_of_mass_z                              162 non-null    float64
#  7   center_of_mass_%submerged                     162 non-null    int64
#  8   traction_multiplier                           162 non-null    float64
#  9   traction_loss                                 162 non-null    float64
#  10  traction_bias(%)                              162 non-null    float64
#  11  #_of_gears                                    162 non-null    int64
#  12  max_velocity(km/h)                            162 non-null    float64
#  13  acceleration(ms^2)                            162 non-null    float64
#  14  interia                                       162 non-null    float64
#  15  drive_type                                    162 non-null    category
#  16  engine_type                                   162 non-null    category
#  17  brakes_deceleration(ms^2)                     162 non-null    float64
#  18  brakes_bias(%)                                162 non-null    float64
#  19  abs                                           162 non-null    int64
#  20  steering_lock_(°)                             162 non-null    float64
#  21  suspension_force_level                        162 non-null    float64
#  22  suspension_damping_level                      162 non-null    float64
#  23  suspension_high_speed_com_damping             162 non-null    float64
#  24  suspension_lines_upper_limit                  162 non-null    float64
#  25  suspension_lines_lower_limit                  162 non-null    float64
#  26  suspension_lines_bias_between_front_and_rear  162 non-null    float64
#  27  suspension_anti-dive_multiplier               162 non-null    float64
#  28  seat_offset_distance                          162 non-null    float64
#  29  collision_damage_multiplier                   162 non-null    float64
#  30  monetary_value_($)                            162 non-null    int64
#  31  model_flags                                   162 non-null    object
#  32  handling_flags                                162 non-null    object
#  33  lights_front                                  162 non-null    object
#  34  lights_rear                                   162 non-null    object
#  35  lights_anim_group                             162 non-null    float64
# dtypes: category(2), float64(25), int64(4), object(5)
# memory usage: 43.7+ KB

# %%
df.describe(include='all').T
# Out:
#                                               count unique       top freq  \
# identifier                                      162    162  LANDSTAL    1
# mass_(kg)                                     162.0    NaN       NaN  NaN
# turn_mass_(kg)                                162.0    NaN       NaN  NaN
# drag_multiplier                               162.0    NaN       NaN  NaN
# center_of_mass_x                              162.0    NaN       NaN  NaN
# center_of_mass_y                              162.0    NaN       NaN  NaN
# center_of_mass_z                              162.0    NaN       NaN  NaN
# center_of_mass_%submerged                     162.0    NaN       NaN  NaN
# traction_multiplier                           162.0    NaN       NaN  NaN
# traction_loss                                 162.0    NaN       NaN  NaN
# traction_bias(%)                              162.0    NaN       NaN  NaN
# #_of_gears                                    162.0    NaN       NaN  NaN
# max_velocity(km/h)                            162.0    NaN       NaN  NaN
# acceleration(ms^2)                            162.0    NaN       NaN  NaN
# interia                                       162.0    NaN       NaN  NaN
# drive_type                                      162      3      Rear  111
# engine_type                                     162      3    Petrol   96
# brakes_deceleration(ms^2)                     162.0    NaN       NaN  NaN
# brakes_bias(%)                                162.0    NaN       NaN  NaN
# abs                                           162.0    NaN       NaN  NaN
# steering_lock_(°)                             162.0    NaN       NaN  NaN
# suspension_force_level                        162.0    NaN       NaN  NaN
# suspension_damping_level                      162.0    NaN       NaN  NaN
# suspension_high_speed_com_damping             162.0    NaN       NaN  NaN
# suspension_lines_upper_limit                  162.0    NaN       NaN  NaN
# suspension_lines_lower_limit                  162.0    NaN       NaN  NaN
# suspension_lines_bias_between_front_and_rear  162.0    NaN       NaN  NaN
# suspension_anti-dive_multiplier               162.0    NaN       NaN  NaN
# seat_offset_distance                          162.0    NaN       NaN  NaN
# collision_damage_multiplier                   162.0    NaN       NaN  NaN
# monetary_value_($)                            162.0    NaN       NaN  NaN
# model_flags                                     162     76         0   25
# handling_flags                                  162     68         0   25
# lights_front                                    162      4      Long   92
# lights_rear                                     162      6     Small  125
# lights_anim_group                             162.0    NaN       NaN  NaN
#
#                                                       mean           std  \
# identifier                                             NaN           NaN
# mass_(kg)                                      2964.506173   3493.732997
# turn_mass_(kg)                                13925.076543  29343.371204
# drag_multiplier                                   2.828395      2.166557
# center_of_mass_x                                       0.0           0.0
# center_of_mass_y                                  0.041975      0.191181
# center_of_mass_z                                 -0.117222      0.155421
# center_of_mass_%submerged                        77.962963      7.931296
# traction_multiplier                               0.719815       0.18091
# traction_loss                                     0.808333      0.063356
# traction_bias(%)                                  0.495432      0.036014
# #_of_gears                                         4.82716      1.321491
# max_velocity(km/h)                              156.228395     34.504167
# acceleration(ms^2)                               22.679012      6.611353
# interia                                          18.228395     19.741269
# drive_type                                             NaN           NaN
# engine_type                                            NaN           NaN
# brakes_deceleration(ms^2)                         7.097407      2.333243
# brakes_bias(%)                                    0.512346      0.112832
# abs                                                    0.0           0.0
# steering_lock_(°)                                31.376543      3.784597
# suspension_force_level                            1.219753      0.390189
# suspension_damping_level                          0.097346      0.039213
# suspension_high_speed_com_damping                 0.537037      1.500058
# suspension_lines_upper_limit                      0.309506      0.082904
# suspension_lines_lower_limit                      -0.17142      0.090381
# suspension_lines_bias_between_front_and_rear      0.487099      0.058678
# suspension_anti-dive_multiplier                   0.164815      0.195595
# seat_offset_distance                               0.31216      0.142966
# collision_damage_multiplier                       0.437654      0.177567
# monetary_value_($)                            25675.925926  19092.978793
# model_flags                                            NaN           NaN
# handling_flags                                         NaN           NaN
# lights_front                                           NaN           NaN
# lights_rear                                            NaN           NaN
# lights_anim_group                                 3.833333      7.273068
#
#                                                 min      25%      50%  \
# identifier                                      NaN      NaN      NaN
# mass_(kg)                                     100.0   1412.5   1775.0
# turn_mass_(kg)                                 24.1  3066.95   4350.0
# drag_multiplier                                 1.0      2.0      2.2
# center_of_mass_x                                0.0      0.0      0.0
# center_of_mass_y                               -0.8      0.0      0.0
# center_of_mass_z                               -0.6     -0.2     -0.1
# center_of_mass_%submerged                      50.0     70.0     75.0
# traction_multiplier                            0.45     0.65      0.7
# traction_loss                                  0.65      0.8      0.8
# traction_bias(%)                               0.35     0.48      0.5
# #_of_gears                                      1.0      4.0      5.0
# max_velocity(km/h)                             60.0    141.0    160.0
# acceleration(ms^2)                             12.0     18.0     22.0
# interia                                         5.0     10.0     15.0
# drive_type                                      NaN      NaN      NaN
# engine_type                                     NaN      NaN      NaN
# brakes_deceleration(ms^2)                      3.17      5.4      7.0
# brakes_bias(%)                                  0.2     0.45      0.5
# abs                                             0.0      0.0      0.0
# steering_lock_(°)                              25.0     30.0     30.0
# suspension_force_level                          0.4      1.0      1.2
# suspension_damping_level                       0.02     0.07     0.09
# suspension_high_speed_com_damping               0.0      0.0      0.0
# suspension_lines_upper_limit                    0.0     0.27      0.3
# suspension_lines_lower_limit                   -1.0     -0.2    -0.15
# suspension_lines_bias_between_front_and_rear   0.25      0.5      0.5
# suspension_anti-dive_multiplier                 0.0      0.0      0.0
# seat_offset_distance                           0.15     0.21     0.26
# collision_damage_multiplier                    0.05      0.3      0.5
# monetary_value_($)                            500.0  15000.0  22000.0
# model_flags                                     NaN      NaN      NaN
# handling_flags                                  NaN      NaN      NaN
# lights_front                                    NaN      NaN      NaN
# lights_rear                                     NaN      NaN      NaN
# lights_anim_group                               0.0      0.0      0.0
#
#                                                    75%       max
# identifier                                         NaN       NaN
# mass_(kg)                                       3500.0   25500.0
# turn_mass_(kg)                                10917.85  250000.0
# drag_multiplier                                    3.0      20.0
# center_of_mass_x                                   0.0       0.0
# center_of_mass_y                                   0.1       0.5
# center_of_mass_z                                   0.0       0.3
# center_of_mass_%submerged                         85.0     110.0
# traction_multiplier                               0.75       2.5
# traction_loss                                     0.85      0.92
# traction_bias(%)                                  0.52       0.6
# #_of_gears                                         5.0       9.0
# max_velocity(km/h)                               170.0     240.0
# acceleration(ms^2)                                25.0      50.0
# interia                                           25.0     150.0
# drive_type                                         NaN       NaN
# engine_type                                        NaN       NaN
# brakes_deceleration(ms^2)                         8.17      15.0
# brakes_bias(%)                                    0.55       0.8
# abs                                                0.0       0.0
# steering_lock_(°)                                 35.0      50.0
# suspension_force_level                             1.4       3.0
# suspension_damping_level                        0.1175       0.3
# suspension_high_speed_com_damping                  0.0      10.0
# suspension_lines_upper_limit                      0.35      0.47
# suspension_lines_lower_limit                     -0.13       0.0
# suspension_lines_bias_between_front_and_rear       0.5       0.6
# suspension_anti-dive_multiplier                    0.3       0.6
# seat_offset_distance                            0.3675       1.2
# collision_damage_multiplier                       0.54      1.25
# monetary_value_($)                             35000.0  110000.0
# model_flags                                        NaN       NaN
# handling_flags                                     NaN       NaN
# lights_front                                       NaN       NaN
# lights_rear                                        NaN       NaN
# lights_anim_group                                  2.0      28.0

# %% [markdown]
# # Distribution of Key Vehicle Attributes
#
# To better understand how the main numerical features are distributed, let’s take a look at four histograms:
# - vehicle mass,
# - acceleration,
# - top speed,
# - in-game monetary value.
#
# Each histogram includes a KDE (Kernel Density Estimate) line, which gives us a smoothed version of the distribution curve. This helps to visualize the general shape and spread of the data beyond just the bar heights.
#
# These plots allow us to quickly spot skewed distributions, common value ranges and potential outliers - all useful insights for further analysis or preprocessing steps.

# %%
features = ['mass_(kg)', 'acceleration(ms^2)', 'max_velocity(km/h)', 'monetary_value_($)']

plt.figure(figsize=(16, 10))
for i, c in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[c], bins=25, kde=True)
    plt.title(f'Distribution of {c}')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Categorical Features: Drivetrain & Engine Type Distribution
#
# To get a sense of the categorical features in the dataset, I start by visualizing the distribution of drivetrain types across vehicles:
# - Rear-wheel drive (RWD)
# - Front-wheel drive (FWD)
# - All-wheel drive (AWD / 4WD)
#
# This plot shows how many vehicles fall into each category, giving us an idea of which drivetrain type is most common in the game.
#
# Next, I examine the engine type distribution, which shows how many vehicles run on:
# - Petrol
# - Diesel
# - Electric power
#
# Both of these bar plots help us understand the diversity (or lack thereof) in vehicle mechanics, and whether we’re dealing with balanced categories or heavily skewed ones - useful information for modeling and feature encoding later on.

# %%
sns.countplot(x=df['drive_type'], order=['Rear', 'Front', '4'])
plt.title('Drive Type Distribution')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Drive Type Distribution')

# %%
sns.countplot(x=df['engine_type'], order=['Petrol', 'Diesel', 'Electric'])
plt.title('Engine Type Distribution')
# Out:
# Text(0.5, 1.0, 'Engine Type Distribution')

# %% [markdown]
# ## Acceleration by Drivetrain Type: A Boxplot View
#
# To explore how drivetrain type affects vehicle performance, I visualize acceleration grouped by drive type using a boxplot.
#
# Boxplots allow us to compare the distribution, median, and variability of acceleration for each category:
# - Rear-wheel drive
# - Front-wheel drive
# - All-wheel drive
#
# This helps us spot interesting patterns, such as whether a certain drivetrain tends to have better acceleration, more consistency, or more outliers. It's a great way to highlight differences that might not be obvious from summary statistics alone.

# %%
sns.boxplot(x=df['drive_type'], y=df['acceleration(ms^2)'], order=['Rear', 'Front', '4'])
plt.title('Acceleration by Drive Type')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Acceleration by Drive Type')

# %% [markdown]
# ## Mass vs Acceleration: Scatterplot with Drivetrain Highlight
#
# To investigate how a vehicle’s mass relates to its acceleration, I use a scatterplot where each point represents a vehicle, colored by its drive type (FWD, RWD, or AWD).
# This plot helps reveal potential trends - for example, whether heavier cars generally accelerate slower, and how drivetrain types are distributed across the performance spectrum.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='mass_(kg)', y='acceleration(ms^2)', hue='drive_type', data=df)
plt.title('Mass vs Acceleration by Drive Type')
# Out:
# Text(0.5, 1.0, 'Mass vs Acceleration by Drive Type')

# %% [markdown]
# ##  Focused View: Zooming in on Typical Values
#
# The previous scatterplot included a few extreme values (such as ultra-heavy or ultra-fast vehicles), which made it harder to see the general trend. To get a clearer view of the main data cluster, I applied the following filters:
# - Acceleration ≤ 35 m/s²
# - Mass ≤ 10,000 kg
#
# I use sns.lmplot() to display the filtered scatterplot along with regression lines for each drivetrain type. This helps visualize the linear relationship between mass and acceleration.
#
# Key Observation: in general, heavier vehicles should accelerate more slowly, which is expected due to basic physics. However, 4WD (all-wheel drive) vehicles are an exception - their regression line suggests better acceleration as mass increases, likely due to the presence of special-purpose vehicles in this category, which are designed to maintain high performance despite their weight.
#
# The slope of the regression line differs between drivetrain types:
# - For front-wheel drive (FWD) vehicles, acceleration drops off more steeply as mass increases.
# - Rear-wheel drive (RWD) vehicles show a less drastic decline, indicating they may handle additional weight more efficiently.
#
# These patterns reflect not only drivetrain mechanics but also the intended in-game role and tuning of various vehicle types.

# %%
df_filtered = df[(df['mass_(kg)'] <= 10000) & (df['acceleration(ms^2)'] <= 35)]

plt.figure(figsize=(10, 8))
sns.lmplot(x='mass_(kg)', y='acceleration(ms^2)', hue='drive_type', data=df_filtered,
           height = 6, aspect = 1.5)
plt.title('Mass vs Acceleration by Drive Type')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Mass vs Acceleration by Drive Type')

# %% [markdown]
# ## Relationship Between Traction Multiplier and Brakes Bias
#
# Next, I explore the interaction between two important vehicle handling parameters:
# - Traction Multiplier - which affects how well the vehicle grips the road,
# - Brakes Bias (%) - representing the distribution of braking force between the front and rear wheels.
#
# The scatterplot visualizes how these two features relate to each other across all vehicles. Understanding this relationship can help identify if there are common patterns or trade-offs in vehicle tuning - for example, whether cars with higher traction tend to have a front- or rear-biased braking system.
#
# This insight is valuable for interpreting vehicle dynamics in the game and could inform feature engineering or clustering in further analysis.

# %%
sns.scatterplot(x='traction_multiplier', y='brakes_bias(%)', data=df)
plt.title('Traction vs Brake bias')
# Out:
# Text(0.5, 1.0, 'Traction vs Brake bias')

# %% [markdown]
# ## Pairwise Relationships Between Key Technical Features
#
# To get an overview of how the most important technical features relate to each other, I use a pairplot. This kind of plot shows:
# - Distributions of each variable along the diagonal,
# - Scatterplots between all pairs of features in the lower triangle.
#
# The features included in this analysis are:
# - mass (kg)
# - acceleration (m/s²)
# - max_velocity (km/h)
# - traction_multiplier
# - brakes_deceleration (m/s²)
# - collision_damage_multiplier
#
# While the plot is quite dense due to the number of combinations, it allows us to:
# - Quickly spot potential linear or non-linear relationships,
# - Identify clusters or outliers,
# - Detect correlations worth investigating further.
#
# **Note:** This is mostly for exploratory purposes. For deeper analysis, we may later reduce dimensionality or focus on specific relationships separately.

# %%
features1 = ['mass_(kg)', 'acceleration(ms^2)', 'max_velocity(km/h)',
            'traction_multiplier', 'brakes_deceleration(ms^2)', 'collision_damage_multiplier']

sns.pairplot(df[features1])
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Vehicle Rankings: Best and Worst Performers by Key Attributes
#
# After analyzing general patterns across all vehicles and technical features, it's time to focus on individual cars. In this section, I identify and rank the best and worst performers based on specific attributes. This gives us a clearer picture of how certain vehicles stand out within the GTA: San Andreas universe - whether as top-tier sports cars, bulky utility vehicles, or surprisingly tough survivors.
#
# I visualize each ranking using bar plots, where I highlight:
# - Top 15 fastest vehicles (based on max velocity),
# - Top 15 slowest vehicles,
# - Top 10 vehicles with the best acceleration,
# - Top 10 heaviest vehicles,
# - Top 10 most damage-resistant vehicles (based on the collision_damage_multiplier - lower values indicate better durability).
#
# These comparisons help us spot the standout models and perhaps even define "vehicle archetypes" based on in-game performance.

# %%
top_speed = df.sort_values(by='max_velocity(km/h)', ascending=False).head(15)
top_speed
# Out:
#     identifier  mass_(kg)  turn_mass_(kg)  drag_multiplier  center_of_mass_x  \
# 46     TURISMO     1400.0          3000.0              2.0               0.0
# 11    INFERNUS     1400.0          2725.3              1.5               0.0
# 77     SUPERGT     1400.0          2800.0              2.0               0.0
# 101     BULLET     1200.0          2500.0              1.8               0.0
# 15     CHEETAH     1200.0          3000.0              2.0               0.0
# 69     HOTRING     1600.0          4500.0              1.4               0.0
# 117     JESTER     1500.0          3600.0              2.2               0.0
# 147  POLICE_LA     1600.0          4500.0              2.0               0.0
# 118     SULTAN     1400.0          3400.0              2.4               0.0
# 24     PREMIER     1600.0          3921.3              1.8               0.0
# 122      FLASH     1400.0          2998.3              2.2               0.0
# 148  POLICE_SF     1600.0          4500.0              2.0               0.0
# 27     BANSHEE     1400.0          3000.0              2.0               0.0
# 144       CLUB     1400.0          3000.0              2.8               0.0
# 142      EUROS     1400.0          2998.3              2.2               0.0
#
#      center_of_mass_y  center_of_mass_z  center_of_mass_%submerged  \
# 46              -0.30             -0.20                         70
# 11               0.00             -0.25                         70
# 77              -0.20             -0.24                         70
# 101             -0.15             -0.20                         70
# 15              -0.20             -0.20                         70
# 69               0.20             -0.40                         70
# 117              0.00             -0.05                         75
# 147              0.30             -0.10                         75
# 118              0.10             -0.10                         75
# 24              -0.40              0.00                         75
# 122              0.20             -0.10                         75
# 148              0.30             -0.15                         75
# 27               0.00             -0.20                         70
# 144              0.00              0.00                         80
# 142              0.10             -0.10                         75
#
#      traction_multiplier  traction_loss  traction_bias(%)  #_of_gears  \
# 46                  0.75           0.85              0.45           5
# 11                  0.70           0.80              0.50           5
# 77                  0.75           0.86              0.48           5
# 101                 0.75           0.90              0.48           5
# 15                  0.80           0.90              0.50           5
# 69                  0.85           0.80              0.48           5
# 117                 0.85           0.80              0.50           5
# 147                 0.75           0.85              0.50           5
# 118                 0.80           0.80              0.50           5
# 24                  0.75           0.85              0.52           5
# 122                 0.75           0.90              0.50           5
# 148                 0.75           0.85              0.52           5
# 27                  0.75           0.89              0.50           5
# 144                 0.75           0.90              0.49           5
# 142                 0.70           0.80              0.50           5
#
#      max_velocity(km/h)  acceleration(ms^2)  interia drive_type engine_type  \
# 46                240.0                30.0     10.0          4      Petrol
# 11                240.0                30.0     10.0          4      Petrol
# 77                230.0                26.0      5.0       Rear      Petrol
# 101               230.0                30.0     10.0       Rear      Petrol
# 15                230.0                30.0     10.0       Rear      Petrol
# 69                220.0                26.0      5.0       Rear      Petrol
# 117               200.0                28.0     10.0      Front      Petrol
# 147               200.0                25.0     10.0       Rear      Petrol
# 118               200.0                28.0      5.0          4      Petrol
# 24                200.0                22.0     10.0       Rear      Petrol
# 122               200.0                24.0     10.0      Front      Petrol
# 148               200.0                25.0     10.0       Rear      Petrol
# 27                200.0                33.0     10.0       Rear      Petrol
# 144               200.0                30.0     10.0      Front      Petrol
# 142               200.0                24.0      5.0          4      Petrol
#
#      brakes_deceleration(ms^2)  brakes_bias(%)  abs  steering_lock_(°)  \
# 46                        11.0            0.51    0               30.0
# 11                        11.0            0.51    0               30.0
# 77                         8.0            0.52    0               30.0
# 101                        8.0            0.58    0               30.0
# 15                        11.1            0.48    0               35.0
# 69                        10.0            0.52    0               30.0
# 117                       10.0            0.45    0               30.0
# 147                       10.0            0.53    0               35.0
# 118                       10.0            0.50    0               30.0
# 24                        10.0            0.53    0               35.0
# 122                        8.0            0.55    0               30.0
# 148                       10.0            0.53    0               35.0
# 27                         8.0            0.52    0               34.0
# 144                       11.0            0.45    0               30.0
# 142                        8.0            0.55    0               30.0
#
#      suspension_force_level  suspension_damping_level  \
# 46                      1.2                      0.13
# 11                      1.2                      0.19
# 77                      1.0                      0.20
# 101                     1.0                      0.13
# 15                      0.8                      0.20
# 69                      1.5                      0.10
# 117                     1.1                      0.10
# 147                     1.0                      0.12
# 118                     1.2                      0.15
# 24                      1.3                      0.12
# 122                     1.4                      0.15
# 148                     1.1                      0.12
# 27                      1.6                      0.10
# 144                     1.7                      0.10
# 142                     1.2                      0.15
#
#      suspension_high_speed_com_damping  suspension_lines_upper_limit  \
# 46                                 0.0                          0.15
# 11                                 0.0                          0.25
# 77                                 0.0                          0.25
# 101                                5.0                          0.25
# 15                                 0.0                          0.10
# 69                                10.0                          0.29
# 117                                0.0                          0.28
# 147                                0.0                          0.28
# 118                                0.0                          0.28
# 24                                 0.0                          0.28
# 122                                0.0                          0.28
# 148                                0.0                          0.28
# 27                                 5.0                          0.30
# 144                                0.0                          0.28
# 142                                0.0                          0.30
#
#      suspension_lines_lower_limit  \
# 46                          -0.20
# 11                          -0.10
# 77                          -0.10
# 101                         -0.10
# 15                          -0.15
# 69                          -0.16
# 117                         -0.15
# 147                         -0.12
# 118                         -0.20
# 24                          -0.12
# 122                         -0.10
# 148                         -0.17
# 27                          -0.15
# 144                         -0.12
# 142                         -0.10
#
#      suspension_lines_bias_between_front_and_rear  \
# 46                                           0.50
# 11                                           0.50
# 77                                           0.50
# 101                                          0.45
# 15                                           0.50
# 69                                           0.60
# 117                                          0.50
# 147                                          0.55
# 118                                          0.50
# 24                                           0.38
# 122                                          0.50
# 148                                          0.55
# 27                                           0.50
# 144                                          0.50
# 142                                          0.50
#
#      suspension_anti-dive_multiplier  seat_offset_distance  \
# 46                               0.4                  0.17
# 11                               0.4                  0.37
# 77                               0.3                  0.40
# 101                              0.3                  0.15
# 15                               0.6                  0.40
# 69                               0.4                  0.20
# 117                              0.3                  0.25
# 147                              0.0                  0.20
# 118                              0.3                  0.25
# 24                               0.0                  0.20
# 122                              0.3                  0.25
# 148                              0.0                  0.20
# 27                               0.3                  0.15
# 144                              0.0                  0.25
# 142                              0.3                  0.25
#
#      collision_damage_multiplier  monetary_value_($) model_flags  \
# 46                          0.72               95000    40002004
# 11                          0.72               95000    40002004
# 77                          0.54              105000    40002004
# 101                         0.54              105000    c0002004
# 15                          0.54              105000    c0002004
# 69                          0.56               45000    40002004
# 117                         0.60               35000    c0002804
# 147                         0.24               25000    40000000
# 118                         0.60               35000        2800
# 24                          0.24               25000    40000000
# 122                         0.60               35000        2804
# 148                         0.24               25000    40000000
# 27                          0.49               45000        2004
# 144                         0.50               35000        2000
# 142                         0.60               35000    40002804
#
#     handling_flags lights_front lights_rear  lights_anim_group
# 46          C08401        Small       Small                1.0
# 11          C04000        Small       Small                1.0
# 77          208000         Long        Long                1.0
# 101         204000         Long        Long                1.0
# 15          208000         Long        Long                1.0
# 69          C00000        Small       Small                0.0
# 117        4000000        Small       Small                1.0
# 147       10200008         Long       Small                0.0
# 118        4000002        Small       Small                0.0
# 24        10200008         Long       Small                0.0
# 122        4000001        Small       Small                1.0
# 148       10200008         Long       Small                0.0
# 27          200000        Small       Small                1.0
# 144         C00000        Small       Small                0.0
# 142              0        Small       Small                0.0

# %%
plt.figure(figsize=(16, 10))
sns.barplot(y='identifier', x='max_velocity(km/h)', hue='max_velocity(km/h)', data=top_speed, palette='bright')
plt.title('Top 15 Fastest Cars')
# Out:
# Text(0.5, 1.0, 'Top 15 Fastest Cars')

# %%
slowest = df.sort_values(by='max_velocity(km/h)', ascending=True).head(15)
slowest
# Out:
#     identifier  mass_(kg)  turn_mass_(kg)  drag_multiplier  center_of_mass_x  \
# 131    SWEEPER      800.0           632.7              5.0               0.0
# 146      RCCAM      100.0            50.0             20.0               0.0
# 129      MOWER      800.0           500.0              5.0               0.0
# 91    FORKLIFT     1000.0          1354.2              2.0               0.0
# 92     TRACTOR     2000.0          5000.0              3.0               0.0
# 38    RCBANDIT      100.0            24.1              6.0               0.0
# 121    RCTIGER      100.0            24.1              5.0               0.0
# 29       RHINO    25000.0        250000.0              5.0               0.0
# 128       KART      300.0           150.0              5.0               0.0
# 64       DOZER    10000.0         35000.0             20.0               0.0
# 141      FLOAT     5500.0         33187.9              2.0               0.0
# 41     MONSTER     5000.0         20000.0              3.0               0.0
# 127    CSTREAK     5500.0         33187.9              1.0               0.0
# 134      DFT30     5500.0         33187.9              2.0               0.0
# 115   MTRUCK_B     5000.0         20000.0              3.0               0.0
#
#      center_of_mass_y  center_of_mass_z  center_of_mass_%submerged  \
# 131              0.00             -0.30                         80
# 146              0.05             -0.20                         70
# 129              0.00             -0.30                         80
# 91              -0.20             -0.35                         70
# 92               0.00             -0.20                         70
# 38               0.05             -0.10                         70
# 121              0.00             -0.10                         70
# 29               0.00              0.00                         90
# 128              0.00             -0.15                        110
# 64              -0.50             -0.50                         90
# 141              0.00              0.00                         90
# 41               0.00             -0.35                         80
# 127              0.00              0.00                         90
# 134              0.00             -0.20                         90
# 115              0.00             -0.35                         80
#
#      traction_multiplier  traction_loss  traction_bias(%)  #_of_gears  \
# 131                 0.70           0.80              0.46           3
# 146                 0.60           0.90              0.49           1
# 129                 0.70           0.80              0.48           3
# 91                  0.80           0.85              0.50           3
# 92                  0.90           0.85              0.50           4
# 38                  0.80           0.90              0.49           1
# 121                 0.70           0.90              0.49           1
# 29                  2.50           0.80              0.50           4
# 128                 0.90           0.85              0.48           4
# 64                  0.85           0.80              0.60           5
# 141                 0.58           0.80              0.50           4
# 41                  0.65           0.85              0.55           5
# 127                 0.58           0.80              0.50           4
# 134                 0.65           0.80              0.40           5
# 115                 0.65           0.85              0.55           5
#
#      max_velocity(km/h)  acceleration(ms^2)  interia drive_type engine_type  \
# 131                60.0                12.0     30.0       Rear      Petrol
# 146                60.0                50.0     10.0          4    Electric
# 129                60.0                12.0     30.0       Rear      Petrol
# 91                 60.0                20.0     15.0      Front    Electric
# 92                 70.0                20.0     90.0       Rear      Diesel
# 38                 75.0                35.0      5.0          4    Electric
# 121                75.0                35.0     15.0          4    Electric
# 29                 80.0                40.0    150.0          4      Diesel
# 128                90.0                18.0      5.0       Rear      Petrol
# 64                100.0                35.0    150.0          4      Diesel
# 141               110.0                20.0     20.0       Rear      Diesel
# 41                110.0                45.0     25.0          4      Petrol
# 127               110.0                20.0     20.0       Rear      Diesel
# 134               110.0                20.0     20.0       Rear      Diesel
# 115               110.0                45.0     25.0          4      Petrol
#
#      brakes_deceleration(ms^2)  brakes_bias(%)  abs  steering_lock_(°)  \
# 131                       6.10            0.55    0               35.0
# 146                       5.50            0.50    0               25.0
# 129                       6.10            0.55    0               35.0
# 91                        6.00            0.50    0               30.0
# 92                       15.00            0.20    0               50.0
# 38                        5.50            0.50    0               25.0
# 121                       5.00            0.50    0               45.0
# 29                        5.00            0.50    0               35.0
# 128                      15.00            0.20    0               35.0
# 64                        5.00            0.40    0               45.0
# 141                       3.17            0.40    0               30.0
# 41                        7.00            0.45    0               35.0
# 127                       3.17            0.40    0               30.0
# 134                       3.50            0.40    0               30.0
# 115                       7.00            0.45    0               35.0
#
#      suspension_force_level  suspension_damping_level  \
# 131                     1.6                      0.15
# 146                     3.0                      0.30
# 129                     1.0                      0.15
# 91                      2.0                      0.14
# 92                      2.0                      0.12
# 38                      1.6                      0.10
# 121                     1.6                      0.10
# 29                      0.4                      0.02
# 128                     1.5                      0.20
# 64                      1.4                      0.15
# 141                     1.4                      0.06
# 41                      1.5                      0.07
# 127                     1.4                      0.06
# 134                     1.4                      0.06
# 115                     1.5                      0.07
#
#      suspension_high_speed_com_damping  suspension_lines_upper_limit  \
# 131                                0.0                          0.34
# 146                                0.0                          0.15
# 129                                0.0                          0.15
# 91                                 0.0                          0.25
# 92                                 0.0                          0.25
# 38                                 0.0                          0.28
# 121                                0.0                          0.28
# 29                                 0.0                          0.35
# 128                                0.0                          0.25
# 64                                 0.0                          0.25
# 141                                0.0                          0.45
# 41                                 0.0                          0.45
# 127                                0.0                          0.45
# 134                                0.0                          0.45
# 115                                0.0                          0.45
#
#      suspension_lines_lower_limit  \
# 131                         -0.10
# 146                         -0.15
# 129                         -0.05
# 91                          -0.20
# 92                          -0.05
# 38                          -0.08
# 121                         -0.14
# 29                          -0.10
# 128                         -0.04
# 64                          -0.20
# 141                         -0.25
# 41                          -0.30
# 127                         -0.10
# 134                         -0.25
# 115                         -0.30
#
#      suspension_lines_bias_between_front_and_rear  \
# 131                                          0.50
# 146                                          0.50
# 129                                          0.50
# 91                                           0.50
# 92                                           0.50
# 38                                           0.50
# 121                                          0.50
# 29                                           0.50
# 128                                          0.50
# 64                                           0.35
# 141                                          0.55
# 41                                           0.50
# 127                                          0.55
# 134                                          0.55
# 115                                          0.50
#
#      suspension_anti-dive_multiplier  seat_offset_distance  \
# 131                              0.0                  0.30
# 146                              0.0                  0.20
# 129                              0.0                  0.38
# 91                               0.0                  0.26
# 92                               0.0                  0.26
# 38                               0.0                  0.20
# 121                              0.0                  0.20
# 29                               0.0                  0.22
# 128                              0.0                  0.38
# 64                               0.0                  0.45
# 141                              0.0                  0.45
# 41                               0.3                  0.44
# 127                              0.0                  0.65
# 134                              0.0                  0.45
# 115                              0.3                  0.44
#
#      collision_damage_multiplier  monetary_value_($) model_flags  \
# 131                         0.40               15000    40005a00
# 146                         0.05                 500           0
# 129                         0.40               15000    40001b00
# 91                          0.50                9000        1300
# 92                          0.50                9000      201310
# 38                          0.05                 500      440000
# 121                         0.05                 500           0
# 29                          0.09              110000    40008008
# 128                         0.40               15000    40001b00
# 64                          0.20                5000         308
# 141                         0.20                5000           8
# 41                          0.35               40000          28
# 127                         0.20                5000           8
# 134                         0.20                5000        4008
# 115                         0.35               40000          28
#
#     handling_flags lights_front lights_rear  lights_anim_group
# 131        1308201        Small         Big                0.0
# 146        1000000         Long       Small                0.0
# 129        1308001        Small         Big               28.0
# 91         1040024        Small       Small                0.0
# 92         1340005        Small       Small               28.0
# 38               0         Long       Small                0.0
# 121             40         Long       Small                0.0
# 29          308840         Long       Small               24.0
# 128         308201        Small         Big               18.0
# 64          340220         Long       Small               17.0
# 141            200         Long       Small                0.0
# 41         1300045         Long       Small               20.0
# 127            200         Long       Small               21.0
# 134            200         Long       Small                2.0
# 115        1300045         Long       Small               20.0

# %%
plt.figure(figsize=(16, 10))
sns.barplot(y='identifier', x='max_velocity(km/h)', hue='max_velocity(km/h)', data=slowest, palette='bright')
plt.title('Top 15 Slowest Cars')
# Out:
# Text(0.5, 1.0, 'Top 15 Slowest Cars')

# %%
acceleration = df.sort_values(by='acceleration(ms^2)', ascending=False).head(10)
plt.figure(figsize=(16, 10))
sns.barplot(y='identifier', x='acceleration(ms^2)', hue='acceleration(ms^2)', data=acceleration, palette='deep')
plt.title('Top 10 Acceleration')
# Out:
# Text(0.5, 1.0, 'Top 10 Acceleration')

# %%
heaviest = df.sort_values(by='mass_(kg)', ascending=False).head(10)
plt.figure(figsize=(16, 10))
sns.barplot(x='identifier', y='mass_(kg)', hue='mass_(kg)', data=heaviest)
plt.title('Top 10 Heaviest Vehicles')
# Out:
# Text(0.5, 1.0, 'Top 10 Heaviest Vehicles')

# %%
toughest = df.sort_values(by='collision_damage_multiplier', ascending=True).head(10)
plt.figure(figsize=(16, 10))
sns.barplot(x='identifier', y='collision_damage_multiplier', hue='collision_damage_multiplier', data=toughest, palette='flare')
plt.title('Top 10 Most Damage-Resistant Vehicles (Lower = Tougher)')
# Out:
# Text(0.5, 1.0, 'Top 10 Most Damage-Resistant Vehicles (Lower = Tougher)')

# %% [markdown]
# # Exploring Relationships Between Vehicle Attributes
#
# In this section, we examine pairwise relationships between key features using regplot, which overlays a regression line to help visualize linear trends. These plots allow us to investigate how different characteristics influence each other - especially when it comes to price, speed, and durability.

# %% [markdown]
# ## Max Speed vs Vehicle Price
#
# As expected, vehicles with a higher maximum speed tend to be more expensive. The upward trend in the regression line confirms a strong positive correlation between these two variables.

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x='monetary_value_($)', y='max_velocity(km/h)', data=df)
plt.title('Car Price vs Top Speed')
# Out:
# Text(0.5, 1.0, 'Car Price vs Top Speed')

# %% [markdown]
# ## Acceleration vs Vehicle Price
#
# A similar pattern holds for acceleration - cars that accelerate faster also come with a higher price tag. This suggests that performance clearly influences in-game value.

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x='monetary_value_($)', y='acceleration(ms^2)', data=df)
plt.title('Car Price vs Acceleration')
# Out:
# Text(0.5, 1.0, 'Car Price vs Acceleration')

# %% [markdown]
# ## Collision Damage Multiplier vs Mass
#
# Interestingly, heavier vehicles tend to have a lower collision damage multiplier, meaning they're more resistant to damage. The slight downward slope of the regression line supports this trend - bulkier vehicles can take more punishment.

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x='mass_(kg)', y='collision_damage_multiplier', data=df)
plt.title('Are heavier vehicles more durable?')
# Out:
# Text(0.5, 1.0, 'Are heavier vehicles more durable?')

# %% [markdown]
# ## Acceleration vs Max Speed
#
# Surprisingly, the regression line here is almost completely flat, indicating no clear relationship between a vehicle’s top speed and its acceleration.
# This suggests that in GTA: San Andreas, a car can reach high speeds without necessarily having strong acceleration, and vice versa. It might reflect the arcade-style balancing of vehicles in the game, where those traits are designed independently for gameplay variety.
#
# In a real-world context, we'd expect some correlation here - but this flat line reminds us we're in a game world, not a wind tunnel.

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x='max_velocity(km/h)', y='acceleration(ms^2)', data=df)
plt.title('Top Speed vs Acceleration')
# Out:
# Text(0.5, 1.0, 'Top Speed vs Acceleration')

# %% [markdown]
# # Final Thoughts
#
# Throughout this exploratory data analysis, we took a deep dive into the technical attributes and performance characteristics of vehicles from GTA: San Andreas.
# We started by examining general feature distributions, uncovering relationships between drivetrain types, acceleration, weight, and durability. Then, we shifted our focus to individual vehicles, identifying the fastest, slowest, heaviest, and most damage-resistant cars in the game.
# Finally, we explored pairwise relationships between features like speed, acceleration, mass, and price - revealing both expected trends and some surprising exceptions (like the flat relationship between top speed and acceleration!).
#
# Although there are still more features left to explore, this analysis lays a solid foundation for understanding how the in-game vehicles are designed and balanced - and hopefully inspires further experimentation, modeling, or even just curiosity about Rockstar's vehicle logic.

# %% [markdown]
# ## Thank You!
#
# Thanks for taking the time to explore this dataset with me!
# If you found this notebook interesting or useful, feel free to:
# - Check out [the full dataset](https://www.kaggle.com/datasets/marcelbiezunski/gta-san-andreas-vehicle-stats-full-handling-data) that I carefully compiled for this project.
# - Leave an upvote - it helps others discover this work and motivates me to keep sharing more creative datasets and analyses!
